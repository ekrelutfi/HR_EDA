# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset HR analytics.csv')

# %%
df.head()
# Out:
#                     Employee_Name  EmpID    MarriedID MaritalStatusID  \
# 0                        A Ridwan  10001  Not married          Single
# 1                    Ade Setyanto  10002  Not married          Single
# 2  Adhitya Bramantya Ranggatyasta  10003      Married        Divorced
# 3              Adji Wijaya Kusuma  10004  Not married          Single
# 4                Agus Andri Putra  10005  Not married          Single
#
#   GenderID     EmpStatusID            RoleID LevelID  PerfScoreID Tribe  ...  \
# 0        M  TKP/ Outsource     Product Owner  Senior       Exceed   EWD  ...
# 1        M  TKP/ Outsource     Product Owner  Senior  Fully meets   EWD  ...
# 2        F  TKP/ Outsource     Product Owner  Senior      Average   ENT  ...
# 3        F  TKP/ Outsource  Business Analyst  Middle       Exceed   ENT  ...
# 4        F         Prohire  Business Analyst  Middle      Average   EDU  ...
#
#   DateofTermination         TermReason        EmploymentStatus  \
# ...

# %%
df.GenderID.value_counts()
# Out:
# F    163
# M    124
# Name: GenderID, dtype: int64

# %%
df.EmpStatusID.value_counts()
# Out:
# TKP/ Outsource      217
# Prohire              66
# Karyawan Organik      4
# Name: EmpStatusID, dtype: int64

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'RoleID', 'LevelID', 'PerfScoreID', 'Tribe', 'Squad',
#        'DOB', 'RaceDesc', 'DateofHire', 'DateofTermination', 'TermReason',
#        'EmploymentStatus', 'RecruitmentSource', 'EngagementSurvey',
#        'EmpSatisfaction', 'SpecialProjectsCount', 'LastPerformanceReview_Date',
#        'DaysLateLast30', 'Absences'],
#       dtype='object')

# %%
for i in df.columns.drop(['Employee_Name','EmpID','DOB','DateofHire']):
    print(i)
    print(df[i].value_counts())
    print('----------------------------------------------------')
# Out:
# MarriedID
# Married        152
# Not married    135
# Name: MarriedID, dtype: int64
# ----------------------------------------------------
# MaritalStatusID
# Single      135
# Married      55
# Widowed      50
# Divorced     47
# Name: MaritalStatusID, dtype: int64
# ----------------------------------------------------
# GenderID
# F    163
# M    124
# Name: GenderID, dtype: int64
# ----------------------------------------------------
# EmpStatusID
# TKP/ Outsource      217
# Prohire              66
# Karyawan Organik      4
# Name: EmpStatusID, dtype: int64
# ----------------------------------------------------
# RoleID
# Back End Developer          107
# Front End Developer          70
# Mobile Developer Android     24
# Product Owner                17
# Business Analyst             16
# UI Designer                  15
# System Documentation         10
# UX Designer                   9
# UX Writer                     4
# Mobile Developer iOS          3
# ...

# %%
sns.countplot(df.MaritalStatusID)
plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot(data=df,x='GenderID', kind='count')

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'RoleID', 'LevelID', 'PerfScoreID', 'Tribe', 'Squad',
#        'DOB', 'RaceDesc', 'DateofHire', 'DateofTermination', 'TermReason',
#        'EmploymentStatus', 'RecruitmentSource', 'EngagementSurvey',
#        'EmpSatisfaction', 'SpecialProjectsCount', 'LastPerformanceReview_Date',
#        'DaysLateLast30', 'Absences'],
#       dtype='object')

# %%
df_active = df[df['EmploymentStatus']=='Active']

# %%
plt.figure(figsize=(10,7))
plt.tight_layout()
ax = sns.countplot(df_active['EmpStatusID'])
plt.title('Employee_status_ID', fontsize=22)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.legend(loc='upper right')
#plt.savefig('emp_status_id.png',bbox_inches="tight", dpi=300)
plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,7))
plt.tight_layout()
ax = sns.countplot(df_active['EmpStatusID'], hue=df_active['RoleID'])
plt.title('Employee_status_ID', fontsize=22)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.legend(loc='upper right')
#plt.savefig('emp_status_id.png',bbox_inches="tight", dpi=300)
plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,7))
plt.tight_layout()
ax = sns.countplot(df_active['Tribe'])
plt.title('Tribe', fontsize=22)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
#plt.legend(loc='upper right')
#plt.savefig('Tribe.png',bbox_inches="tight", dpi=300)
plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(18,10))
plt.tight_layout()
ax = sns.countplot(y=df_active['Squad'])
plt.title('Squad', fontsize=22)

total = len(df_active['Squad'])
for p in ax.patches:
        percentage = '{:.0f}'.format(p.get_width())
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
        
#plt.savefig('Squad.png',bbox_inches="tight", dpi=300)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Lenovo\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(8,16))
sns.heatmap(df_active.groupby(['Squad','RoleID'])['EmpID'].count().unstack().reset_index().fillna(0).set_index('Squad'), cmap='Blues', annot=True)
plt.tight_layout()
#plt.savefig('squad role.png', dpi=300, )
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df_active.groupby(['RoleID','Squad'])['EmpID'].count().unstack().reset_index().fillna(0).set_index('RoleID'), cmap='Blues', annot=True)
plt.title('Squad, RoleID')
plt.tight_layout()
#plt.savefig('role_squad.png', dpi=300, )
plt.show()

# %%
plt.figure(figsize=(16,9))
g=sns.heatmap(df_active.groupby(['Squad','Tribe'])['EmpID'].count().unstack().reset_index().fillna(0).set_index('Squad'), cmap='Blues')
g.set_yticklabels(g.get_yticklabels(), rotation = 0, fontsize = 8)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df_active.groupby(['RoleID','Tribe'])['EmpID'].count().unstack().reset_index().fillna(0).set_index('RoleID'), cmap='Blues', annot=True)
plt.title('RoleID,Tribe')
plt.tight_layout()
#plt.savefig('role_tribe.png', dpi=300, )

plt.show()

# %%
plt.figure(figsize=(10,7))
ax=sns.countplot(df_active['RoleID'])
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('RoleID')
plt.xticks(rotation=90)
plt.tight_layout()
#plt.savefig('role.png', dpi=300, )

plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_active['PerfScoreID'].unique()
# Out:
# array(['Exceed', 'Fully meets', 'Average', 'Need improvement',
#        'Special treatment'], dtype=object)

# %%
df_active.PerfScoreID.value_counts()
# Out:
# Average              58
# Fully meets          52
# Exceed               46
# Need improvement     23
# Special treatment    15
# Name: PerfScoreID, dtype: int64

# %%
plt.figure(figsize=(10,7))
ax=sns.countplot(df_active['PerfScoreID'], order=['Exceed', 'Fully meets','Average', 'Need improvement', 'Special treatment'])
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('Performance Score')
plt.xticks(rotation=90)
plt.tight_layout()
#plt.savefig('PerfScore.png', dpi=300, )

plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,7))
ax=sns.countplot(data=df_active, x='PerfScoreID', hue='EmpSatisfaction', order=['Exceed', 'Fully meets','Average', 'Need improvement', 
       'Special treatment'])
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('Performance Score, Emp. Satisfaction', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
#plt.savefig('PerfScore-empsatisfaction.png', dpi=300, )

plt.show()

# %%
df_active['PerfScoreID'].unique()
# Out:
# array(['Exceed', 'Average', 'Need improvement', 'Fully meets',
#        'Special treatment'], dtype=object)

# %%
plt.figure(figsize=(10,7))
ax=sns.countplot(data=df_active, x='EmpStatusID', hue='EmpSatisfaction',) #order=['Exceed', 'Fully meets','Average', 'Need improvement', 
       #'Special treatment'])
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('Employee Status, Emp. Satisfaction', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')
#plt.savefig('EmpStatus-empsatisfaction.png', dpi=300, )

plt.show()

# %%
plt.figure(figsize=(10,7))
ax=sns.countplot(data=df_active, x='EmpStatusID', hue='PerfScoreID',hue_order=['Exceed', 'Fully meets','Average', 
                                                                                        'Need improvement','Special treatment'])
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('Employee Status, Performance Score', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')
#plt.savefig('EmpStatus-perfscore.png', dpi=300, )

plt.show()

# %%
df_inactive=df[df.TermReason!= 'N/A-StillEmployed']

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(data=df_inactive, x='TermReason', order=df_inactive.TermReason.value_counts().index)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('Alasan Keluar', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
#plt.legend(loc='upper right')
#plt.savefig('TermReason.png', dpi=300, )

plt.show()

# %%
df_inactive.RecruitmentSource.value_counts()
# Out:
# Google Search              27
# Indeed                     21
# LinkedIn                   15
# Diversity Job Fair         14
# CareerBuilder              10
# Employee Referral           4
# On-line Web application     1
# Other                       1
# Name: RecruitmentSource, dtype: int64

# %%
df_active.PerfScoreID.unique()
# Out:
# array(['Exceed', 'Average', 'Need improvement', 'Fully meets',
#        'Special treatment'], dtype=object)

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(data=df, x='RecruitmentSource',order=df.RecruitmentSource.value_counts().index)# hue='PerfScoreID', hue_order=['Exceed', 'Fully meets','Average', 
                                                       #                                 'Need improvement','Special treatment'])
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('Recruitment Source', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
#plt.legend(loc='upper right')
#plt.savefig('Recruitment Source.png', dpi=300, )

plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(data=df, x='RecruitmentSource', hue='PerfScoreID', 
                 order=df.RecruitmentSource.value_counts().index, hue_order=['Exceed', 'Fully meets','Average', 
                                                                                        'Need improvement','Special treatment'])
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('Recruitment Source, PerfScore', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')
#plt.savefig('Recruitment Source, PerfScore.png', dpi=300, )

plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(data=df_inactive, x='TermReason', hue='EmploymentStatus',) 
                 #order=df.RecruitmentSource.value_counts().index, hue_order=['Exceed', 'Fully meets','Average', 
                                                                                       # 'Need improvement','Special treatment'])
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('Alasan mengundurkan diri / dipecat', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')
#plt.savefig('Alasan_mengundurkan_diri/dipecat.png', dpi=300, )

plt.show()
